# %%
#Necessary Imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV

# %%
#Preprocessing
data_path = 'NYC_Property_Sales_Apartments.csv' 
data = pd.read_csv(data_path)

#Filter our data to remove potential outliers.
filtered_data = data[
    (data['gross_square_feet'] > 100) & (data['gross_square_feet'] < 20000) &
    (data['sale_price'] > 50000) & (data['sale_price'] < 10000000)
]

features = filtered_data[['borough', 'neighborhood', 'gross_square_feet']]
target = filtered_data['sale_price']

column_transformer = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), ['borough', 'neighborhood'])
], remainder='passthrough')

features_encoded = column_transformer.fit_transform(features)

# %%
#Split our data set
X_train, X_test, y_train, y_test = train_test_split(features_encoded, target, test_size=0.2, random_state=42)

# %%
#Train our model
model = RandomForestRegressor(
    n_estimators=1000,
    max_depth=None,
    min_samples_split=20,
    min_samples_leaf=1,
    max_features='sqrt',
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=  17.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=500; total time=   5.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   3.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   3.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   6.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  30.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=   6.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  10.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=  10.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=   7.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=   6.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   2.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   9.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=200; total time=   8.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  38.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  12.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   5.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  26.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   8.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  18.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=1000; total time=  12.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  37.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   5.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  27.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   9.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=  18.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=200; total time=   4.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=  27.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=   8.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=   6.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=500; total time=   5.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  52.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  12.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  13.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  22.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   9.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=   6.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=500; total time=   6.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  12.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  12.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  23.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  18.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=   5.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  10.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   4.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   5.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  27.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  17.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  11.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   8.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  11.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  12.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=  13.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  17.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  18.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=   4.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=200; total time=   7.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  38.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  26.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=  28.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=1000; total time=  11.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=   5.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=200; total time=   4.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  22.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   8.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=  18.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=   4.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=  11.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=  26.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=   8.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=   6.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=1000; total time=  10.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=  11.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  17.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=   8.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=   5.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=1000; total time=   9.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=  12.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=  30.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  20.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   9.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  27.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   4.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  16.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   5.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  25.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=  11.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   8.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   9.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=   6.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20, n_estimators=1000; total time=   9.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=200; total time=   4.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=  13.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   9.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  17.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=1000; total time=   8.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=1000; total time=  11.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=1000; total time=   7.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=  15.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  15.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  24.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  10.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; total time=  19.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=20, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=20, n_estimators=500; total time=   6.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=1000; total time=  13.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   1.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  20.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  16.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   5.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  25.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=500; total time=  13.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  18.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  18.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=1000; total time=   8.4s
# RandomForestRegressor(max_features='sqrt', min_samples_split=20,
#                       n_estimators=1000, random_state=42)

# %%
#Predict and Evaluate
y_pred = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"Random Forest RMSE: {rmse:.2f}")
print(f"Random Forest R^2: {r2:.2f}")
# Out:
# Random Forest RMSE: 698116.66
# Random Forest R^2: 0.69

# %%
#Change the inputs in input_data to see different prices that the model spits out. 

input_data = {
    'borough': ['Manhattan'],
    'neighborhood': ['Tribeca'],
    'gross_square_feet': [600]
}

input_df = pd.DataFrame(input_data)

transformed_input = column_transformer.transform(input_df)

predicted_price = model.predict(transformed_input)

print(f"Predicted Sale Price for the property: ${predicted_price[0]:,.2f}")
# Out:
# Predicted Sale Price for the property: $924,292.50
